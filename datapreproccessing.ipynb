# %%
import numpy as np
import pandas as pd
from sklearn import svm
#https://scikit-learn.org/stable/modules/preprocessing.html#preprocessing
from sklearn import preprocessing

# %%
df = pd.read_excel("c:\\Out.xlsx")
# Out:
# (25029, 24)

# %%
df.shape
# Out:
# (25029, 24)

# %%
df.tail()
# Out:
#                                     name  \
# 25024  Jeogboj Babbe Jocozniizc jeogb39b
# 25025               Soifd Voffi w5595rvl
# 25026                       W551PL6H-I50
# 25027                ZI853_UTMOBXG_553_B
# 25028   Gizboj Gobgeo Ryoggozas gizbo52g
#
#                                        distinguishedName       sn  \
# 25024  CN=Jeogboj Babbe Jocozniizc jeogb39b,OU=CR,OU=...  Jeogboj
# 25025  CN=Soifd Voffi w5595rvl,OU=Abozb,OU=_Fojmzig,O...    Soifd
# 25026  CN=W551PL6H-I50,OU=SzekegonocIffuajmb,OU=Abozb...      NaN
# 25027  CN=ZI853_UTMOBXG_553_B,OU=BozkefoIffuajmb,OU=A...      NaN
# 25028  CN=Gizboj Gobgeo Ryoggozas gizbo52g,OU=CR,OU=A...   Gizboj
#
#               givenName  Enabled                       mail  \
# 25024  Babbe Jocozniizc     True  babbe.jeogboj@beohojb.fuh
# 25025             Voffi     True                        NaN
# 25026               NaN     True                        NaN
# 25027               NaN     True                        NaN
# ...

# %%
df.head()
